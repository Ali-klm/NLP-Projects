# %% [markdown]
# # part one

# %% [markdown]
# **imdb**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Flatten, Conv1D, MaxPooling1D
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

def train_model_with_cnn(embedding_dim, X_train, y_train, X_test, y_test, max_words, filters, kernel_size, use_maxpool):
    model = Sequential()
    model.add(Embedding(max_words, embedding_dim, input_length=50))
    model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='relu'))
    if use_maxpool:
        model.add(MaxPooling1D())
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.fit(X_train, y_train, epochs=5, batch_size=64, validation_split=0.2)

    y_pred = (model.predict(X_test) > 0.5).astype("int32")

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    print("Evaluation Metrics:")
    print(f"Accuracy: {accuracy:.5f}")
    print(f"Precision: {precision:.5f}")
    print(f"Recall: {recall:.5f}")
    print(f"F1 Score: {f1:.5f}")
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))

# Load IMDB dataset with a maximum of 10000 words
(X_train_imdb, y_train_imdb), (X_test_imdb, y_test_imdb) = imdb.load_data(num_words=10000)
max_words_imdb = 10000

# Pad sequences
maxlen = 50
X_train_imdb = sequence.pad_sequences(X_train_imdb, maxlen=maxlen)
X_test_imdb = sequence.pad_sequences(X_test_imdb, maxlen=maxlen)

configs = [
    (16, 5, False), (16, 5, True), (16, 7, False), (16, 7, True),
    (32, 5, False), (32, 5, True), (32, 7, False), (32, 7, True)
]

embedding_dims = [10, 32, 64, 100]

for embedding_dim in embedding_dims:
    for filters, kernel_size, use_maxpool in configs:
        print(f"Training model with Embedding Dimension: {embedding_dim}, filters={filters}, kernel_size={kernel_size}, maxpool={use_maxpool}")
        train_model_with_cnn(embedding_dim, X_train_imdb, y_train_imdb, X_test_imdb, y_test_imdb, max_words_imdb, filters, kernel_size, use_maxpool)
# Out:
# Training model with Embedding Dimension: 10, filters=16, kernel_size=5, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 4s 8ms/step - loss: 0.5636 - accuracy: 0.6712 - val_loss: 0.4171 - val_accuracy: 0.8092
# Epoch 2/5
# 313/313 [==============================] - 2s 8ms/step - loss: 0.3249 - accuracy: 0.8623 - val_loss: 0.4396 - val_accuracy: 0.7978
# Epoch 3/5
# 313/313 [==============================] - 3s 10ms/step - loss: 0.2030 - accuracy: 0.9229 - val_loss: 0.4949 - val_accuracy: 0.7946
# Epoch 4/5
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0940 - accuracy: 0.9716 - val_loss: 0.6994 - val_accuracy: 0.7792
# Epoch 5/5
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0317 - accuracy: 0.9931 - val_loss: 0.8556 - val_accuracy: 0.7808
# 782/782 [==============================] - 3s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.78452
# Precision: 0.78046
# Recall: 0.79176
# F1 Score: 0.78607
# Confusion Matrix:
# [[9716 2784]
#  [2603 9897]]
# Training model with Embedding Dimension: 10, filters=16, kernel_size=5, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 3s 8ms/step - loss: 0.5906 - accuracy: 0.6393 - val_loss: 0.4259 - val_accuracy: 0.7992
# Epoch 2/5
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3367 - accuracy: 0.8557 - val_loss: 0.4093 - val_accuracy: 0.8104
# Epoch 3/5
# 313/313 [==============================] - 2s 8ms/step - loss: 0.2255 - accuracy: 0.9125 - val_loss: 0.4612 - val_accuracy: 0.8008
# Epoch 4/5
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1307 - accuracy: 0.9562 - val_loss: 0.5640 - val_accuracy: 0.7914
# Epoch 5/5
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0551 - accuracy: 0.9861 - val_loss: 0.7609 - val_accuracy: 0.7872
# 782/782 [==============================] - 2s 2ms/step
# Evaluation Metrics:
# Accuracy: 0.78592
# Precision: 0.76696
# Recall: 0.82144
# F1 Score: 0.79326
# Confusion Matrix:
# [[ 9380  3120]
#  [ 2232 10268]]
# Training model with Embedding Dimension: 10, filters=16, kernel_size=7, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 4s 8ms/step - loss: 0.5338 - accuracy: 0.7038 - val_loss: 0.4129 - val_accuracy: 0.8048
# Epoch 2/5
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3204 - accuracy: 0.8627 - val_loss: 0.4186 - val_accuracy: 0.8052
# Epoch 3/5
# 313/313 [==============================] - 3s 10ms/step - loss: 0.2152 - accuracy: 0.9154 - val_loss: 0.4857 - val_accuracy: 0.7962
# Epoch 4/5
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1083 - accuracy: 0.9627 - val_loss: 0.6794 - val_accuracy: 0.7846
# Epoch 5/5
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0363 - accuracy: 0.9911 - val_loss: 0.8957 - val_accuracy: 0.7828
# 782/782 [==============================] - 2s 2ms/step
# Evaluation Metrics:
# Accuracy: 0.78172
# Precision: 0.76428
# Recall: 0.81472
# F1 Score: 0.78869
# Confusion Matrix:
# [[ 9359  3141]
#  [ 2316 10184]]
# Training model with Embedding Dimension: 10, filters=16, kernel_size=7, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 6s 17ms/step - loss: 0.5471 - accuracy: 0.6913 - val_loss: 0.4143 - val_accuracy: 0.8090
# Epoch 2/5
# 313/313 [==============================] - 4s 12ms/step - loss: 0.3276 - accuracy: 0.8618 - val_loss: 0.4120 - val_accuracy: 0.8128
# Epoch 3/5
# 313/313 [==============================] - 3s 11ms/step - loss: 0.2347 - accuracy: 0.9056 - val_loss: 0.4662 - val_accuracy: 0.7958
# Epoch 4/5
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1464 - accuracy: 0.9491 - val_loss: 0.5787 - val_accuracy: 0.7908
# Epoch 5/5
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0677 - accuracy: 0.9811 - val_loss: 0.7438 - val_accuracy: 0.7856
# 782/782 [==============================] - 3s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.78452
# Precision: 0.78242
# Recall: 0.78824
# F1 Score: 0.78532
# Confusion Matrix:
# [[9760 2740]
#  [2647 9853]]
# Training model with Embedding Dimension: 10, filters=32, kernel_size=5, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 4s 11ms/step - loss: 0.5357 - accuracy: 0.6936 - val_loss: 0.4055 - val_accuracy: 0.8136
# Epoch 2/5
# 313/313 [==============================] - 6s 19ms/step - loss: 0.3074 - accuracy: 0.8713 - val_loss: 0.4075 - val_accuracy: 0.8120
# Epoch 3/5
# 313/313 [==============================] - 4s 14ms/step - loss: 0.2009 - accuracy: 0.9230 - val_loss: 0.4804 - val_accuracy: 0.8010
# Epoch 4/5
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1049 - accuracy: 0.9662 - val_loss: 0.6272 - val_accuracy: 0.7890
# Epoch 5/5
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0419 - accuracy: 0.9893 - val_loss: 0.8210 - val_accuracy: 0.7870
# 782/782 [==============================] - 5s 5ms/step
# Evaluation Metrics:
# Accuracy: 0.78948
# Precision: 0.78254
# Recall: 0.80176
# F1 Score: 0.79203
# Confusion Matrix:
# [[ 9715  2785]
#  [ 2478 10022]]
# Training model with Embedding Dimension: 10, filters=32, kernel_size=5, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 5s 14ms/step - loss: 0.5397 - accuracy: 0.6996 - val_loss: 0.4150 - val_accuracy: 0.8024
# Epoch 2/5
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3275 - accuracy: 0.8590 - val_loss: 0.4333 - val_accuracy: 0.8042
# Epoch 3/5
# 313/313 [==============================] - 6s 18ms/step - loss: 0.2437 - accuracy: 0.9029 - val_loss: 0.4591 - val_accuracy: 0.8032
# Epoch 4/5
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1685 - accuracy: 0.9380 - val_loss: 0.5395 - val_accuracy: 0.7928
# Epoch 5/5
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0977 - accuracy: 0.9699 - val_loss: 0.6962 - val_accuracy: 0.7870
# 782/782 [==============================] - 2s 2ms/step
# Evaluation Metrics:
# Accuracy: 0.78460
# Precision: 0.81513
# Recall: 0.73616
# F1 Score: 0.77363
# Confusion Matrix:
# [[10413  2087]
#  [ 3298  9202]]
# Training model with Embedding Dimension: 10, filters=32, kernel_size=7, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 4s 9ms/step - loss: 0.5370 - accuracy: 0.6981 - val_loss: 0.4233 - val_accuracy: 0.8030
# Epoch 2/5
# 313/313 [==============================] - 3s 10ms/step - loss: 0.3233 - accuracy: 0.8601 - val_loss: 0.4150 - val_accuracy: 0.8044
# Epoch 3/5
# 313/313 [==============================] - 4s 12ms/step - loss: 0.2282 - accuracy: 0.9104 - val_loss: 0.4900 - val_accuracy: 0.7968
# Epoch 4/5
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1360 - accuracy: 0.9524 - val_loss: 0.6282 - val_accuracy: 0.7900
# Epoch 5/5
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0616 - accuracy: 0.9832 - val_loss: 0.8223 - val_accuracy: 0.7794
# 782/782 [==============================] - 2s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.78768
# Precision: 0.80052
# Recall: 0.76632
# F1 Score: 0.78305
# Confusion Matrix:
# [[10113  2387]
#  [ 2921  9579]]
# Training model with Embedding Dimension: 10, filters=32, kernel_size=7, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 9s 21ms/step - loss: 0.5564 - accuracy: 0.6776 - val_loss: 0.4150 - val_accuracy: 0.8080
# Epoch 2/5
# 313/313 [==============================] - 6s 18ms/step - loss: 0.3286 - accuracy: 0.8603 - val_loss: 0.4349 - val_accuracy: 0.7996
# Epoch 3/5
# 313/313 [==============================] - 3s 9ms/step - loss: 0.2344 - accuracy: 0.9081 - val_loss: 0.4662 - val_accuracy: 0.7992
# Epoch 4/5
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1446 - accuracy: 0.9489 - val_loss: 0.5869 - val_accuracy: 0.7912
# Epoch 5/5
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0666 - accuracy: 0.9812 - val_loss: 0.7538 - val_accuracy: 0.7860
# 782/782 [==============================] - 2s 2ms/step
# Evaluation Metrics:
# Accuracy: 0.78620
# Precision: 0.76982
# Recall: 0.81656
# F1 Score: 0.79250
# Confusion Matrix:
# [[ 9448  3052]
#  [ 2293 10207]]
# Training model with Embedding Dimension: 32, filters=16, kernel_size=5, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 6s 15ms/step - loss: 0.5409 - accuracy: 0.6929 - val_loss: 0.4169 - val_accuracy: 0.8032
# Epoch 2/5
# 313/313 [==============================] - 4s 12ms/step - loss: 0.2933 - accuracy: 0.8766 - val_loss: 0.4168 - val_accuracy: 0.8102
# Epoch 3/5
# 313/313 [==============================] - 4s 12ms/step - loss: 0.1353 - accuracy: 0.9535 - val_loss: 0.5514 - val_accuracy: 0.7958
# Epoch 4/5
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0296 - accuracy: 0.9936 - val_loss: 0.7574 - val_accuracy: 0.7964
# Epoch 5/5
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0051 - accuracy: 0.9996 - val_loss: 0.8657 - val_accuracy: 0.7964
# 782/782 [==============================] - 2s 2ms/step
# Evaluation Metrics:
# Accuracy: 0.79548
# Precision: 0.79924
# Recall: 0.78920
# F1 Score: 0.79419
# Confusion Matrix:
# [[10022  2478]
#  [ 2635  9865]]
# Training model with Embedding Dimension: 32, filters=16, kernel_size=5, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 5s 12ms/step - loss: 0.5272 - accuracy: 0.7099 - val_loss: 0.4090 - val_accuracy: 0.8088
# Epoch 2/5
# 313/313 [==============================] - 5s 15ms/step - loss: 0.2937 - accuracy: 0.8778 - val_loss: 0.4131 - val_accuracy: 0.8088
# Epoch 3/5
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1410 - accuracy: 0.9539 - val_loss: 0.5300 - val_accuracy: 0.7934
# Epoch 4/5
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0340 - accuracy: 0.9938 - val_loss: 0.6948 - val_accuracy: 0.7968
# Epoch 5/5
# 313/313 [==============================] - 4s 12ms/step - loss: 0.0051 - accuracy: 0.9998 - val_loss: 0.8152 - val_accuracy: 0.7966
# 782/782 [==============================] - 2s 2ms/step
# Evaluation Metrics:
# Accuracy: 0.79948
# Precision: 0.79845
# Recall: 0.80120
# F1 Score: 0.79982
# Confusion Matrix:
# [[ 9972  2528]
#  [ 2485 10015]]
# Training model with Embedding Dimension: 32, filters=16, kernel_size=7, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 5s 13ms/step - loss: 0.5204 - accuracy: 0.7150 - val_loss: 0.4261 - val_accuracy: 0.7958
# Epoch 2/5
# 313/313 [==============================] - 4s 14ms/step - loss: 0.2829 - accuracy: 0.8834 - val_loss: 0.4265 - val_accuracy: 0.8090
# Epoch 3/5
# 313/313 [==============================] - 4s 13ms/step - loss: 0.1220 - accuracy: 0.9596 - val_loss: 0.5766 - val_accuracy: 0.7858
# Epoch 4/5
# 313/313 [==============================] - 4s 11ms/step - loss: 0.0251 - accuracy: 0.9949 - val_loss: 0.7884 - val_accuracy: 0.7902
# Epoch 5/5
# 313/313 [==============================] - 4s 11ms/step - loss: 0.0040 - accuracy: 0.9996 - val_loss: 0.8963 - val_accuracy: 0.7854
# 782/782 [==============================] - 3s 4ms/step
# Evaluation Metrics:
# Accuracy: 0.79180
# Precision: 0.80971
# Recall: 0.76288
# F1 Score: 0.78560
# Confusion Matrix:
# [[10259  2241]
#  [ 2964  9536]]
# Training model with Embedding Dimension: 32, filters=16, kernel_size=7, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 5s 13ms/step - loss: 0.5340 - accuracy: 0.7051 - val_loss: 0.4175 - val_accuracy: 0.8042
# Epoch 2/5
# 313/313 [==============================] - 4s 14ms/step - loss: 0.2928 - accuracy: 0.8785 - val_loss: 0.4240 - val_accuracy: 0.8076
# Epoch 3/5
# 313/313 [==============================] - 5s 17ms/step - loss: 0.1365 - accuracy: 0.9542 - val_loss: 0.5412 - val_accuracy: 0.7954
# Epoch 4/5
# 313/313 [==============================] - 4s 12ms/step - loss: 0.0277 - accuracy: 0.9954 - val_loss: 0.7267 - val_accuracy: 0.7956
# Epoch 5/5
# 313/313 [==============================] - 4s 12ms/step - loss: 0.0043 - accuracy: 0.9998 - val_loss: 0.8390 - val_accuracy: 0.7992
# 782/782 [==============================] - 3s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.79480
# Precision: 0.79043
# Recall: 0.80232
# F1 Score: 0.79633
# Confusion Matrix:
# [[ 9841  2659]
#  [ 2471 10029]]
# Training model with Embedding Dimension: 32, filters=32, kernel_size=5, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 5s 13ms/step - loss: 0.5145 - accuracy: 0.7197 - val_loss: 0.4023 - val_accuracy: 0.8136
# Epoch 2/5
# 313/313 [==============================] - 5s 14ms/step - loss: 0.2808 - accuracy: 0.8859 - val_loss: 0.4180 - val_accuracy: 0.8090
# Epoch 3/5
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1152 - accuracy: 0.9628 - val_loss: 0.5293 - val_accuracy: 0.7942
# Epoch 4/5
# 313/313 [==============================] - 4s 13ms/step - loss: 0.0203 - accuracy: 0.9963 - val_loss: 0.7731 - val_accuracy: 0.7940
# Epoch 5/5
# 313/313 [==============================] - 4s 13ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.8950 - val_accuracy: 0.7950
# 782/782 [==============================] - 3s 4ms/step
# Evaluation Metrics:
# Accuracy: 0.79764
# Precision: 0.79615
# Recall: 0.80016
# F1 Score: 0.79815
# Confusion Matrix:
# [[ 9939  2561]
#  [ 2498 10002]]
# Training model with Embedding Dimension: 32, filters=32, kernel_size=5, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 5s 14ms/step - loss: 0.5212 - accuracy: 0.7191 - val_loss: 0.4054 - val_accuracy: 0.8160
# Epoch 2/5
# 313/313 [==============================] - 5s 16ms/step - loss: 0.2949 - accuracy: 0.8767 - val_loss: 0.4087 - val_accuracy: 0.8100
# Epoch 3/5
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1544 - accuracy: 0.9464 - val_loss: 0.5375 - val_accuracy: 0.7942
# Epoch 4/5
# 313/313 [==============================] - 4s 13ms/step - loss: 0.0426 - accuracy: 0.9893 - val_loss: 0.6890 - val_accuracy: 0.8022
# Epoch 5/5
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0077 - accuracy: 0.9995 - val_loss: 0.8337 - val_accuracy: 0.8002
# 782/782 [==============================] - 3s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.79696
# Precision: 0.78950
# Recall: 0.80984
# F1 Score: 0.79954
# Confusion Matrix:
# [[ 9801  2699]
#  [ 2377 10123]]
# Training model with Embedding Dimension: 32, filters=32, kernel_size=7, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 6s 14ms/step - loss: 0.5338 - accuracy: 0.6983 - val_loss: 0.4291 - val_accuracy: 0.7940
# Epoch 2/5
# 313/313 [==============================] - 6s 18ms/step - loss: 0.2908 - accuracy: 0.8791 - val_loss: 0.4173 - val_accuracy: 0.8090
# Epoch 3/5
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1246 - accuracy: 0.9577 - val_loss: 0.5883 - val_accuracy: 0.7948
# Epoch 4/5
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0190 - accuracy: 0.9964 - val_loss: 0.8207 - val_accuracy: 0.7908
# Epoch 5/5
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.9710 - val_accuracy: 0.7952
# 782/782 [==============================] - 2s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.79612
# Precision: 0.78515
# Recall: 0.81536
# F1 Score: 0.79997
# Confusion Matrix:
# [[ 9711  2789]
#  [ 2308 10192]]
# Training model with Embedding Dimension: 32, filters=32, kernel_size=7, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 5s 14ms/step - loss: 0.5343 - accuracy: 0.7035 - val_loss: 0.4150 - val_accuracy: 0.8044
# Epoch 2/5
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2986 - accuracy: 0.8745 - val_loss: 0.4174 - val_accuracy: 0.8062
# Epoch 3/5
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1485 - accuracy: 0.9488 - val_loss: 0.5305 - val_accuracy: 0.7900
# Epoch 4/5
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0348 - accuracy: 0.9927 - val_loss: 0.7159 - val_accuracy: 0.7922
# Epoch 5/5
# 313/313 [==============================] - 6s 20ms/step - loss: 0.0062 - accuracy: 0.9994 - val_loss: 0.8873 - val_accuracy: 0.7932
# 782/782 [==============================] - 2s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.79440
# Precision: 0.78092
# Recall: 0.81840
# F1 Score: 0.79922
# Confusion Matrix:
# [[ 9630  2870]
#  [ 2270 10230]]
# Training model with Embedding Dimension: 64, filters=16, kernel_size=5, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 10s 28ms/step - loss: 0.5147 - accuracy: 0.7196 - val_loss: 0.3974 - val_accuracy: 0.8152
# Epoch 2/5
# 313/313 [==============================] - 9s 30ms/step - loss: 0.2647 - accuracy: 0.8924 - val_loss: 0.4347 - val_accuracy: 0.8054
# Epoch 3/5
# 313/313 [==============================] - 7s 22ms/step - loss: 0.0805 - accuracy: 0.9757 - val_loss: 0.5928 - val_accuracy: 0.7944
# Epoch 4/5
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0100 - accuracy: 0.9988 - val_loss: 0.7738 - val_accuracy: 0.7970
# Epoch 5/5
# 313/313 [==============================] - 7s 21ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.8638 - val_accuracy: 0.8000
# 782/782 [==============================] - 3s 4ms/step
# Evaluation Metrics:
# Accuracy: 0.80104
# Precision: 0.79298
# Recall: 0.81480
# F1 Score: 0.80374
# Confusion Matrix:
# [[ 9841  2659]
#  [ 2315 10185]]
# Training model with Embedding Dimension: 64, filters=16, kernel_size=5, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 12s 31ms/step - loss: 0.5021 - accuracy: 0.7369 - val_loss: 0.4081 - val_accuracy: 0.8120
# Epoch 2/5
# 313/313 [==============================] - 5s 17ms/step - loss: 0.2711 - accuracy: 0.8885 - val_loss: 0.4230 - val_accuracy: 0.8072
# Epoch 3/5
# 313/313 [==============================] - 6s 20ms/step - loss: 0.1030 - accuracy: 0.9686 - val_loss: 0.5812 - val_accuracy: 0.7980
# Epoch 4/5
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0151 - accuracy: 0.9980 - val_loss: 0.7333 - val_accuracy: 0.7924
# Epoch 5/5
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.8392 - val_accuracy: 0.7948
# 782/782 [==============================] - 2s 2ms/step
# Evaluation Metrics:
# Accuracy: 0.80224
# Precision: 0.79866
# Recall: 0.80824
# F1 Score: 0.80342
# Confusion Matrix:
# [[ 9953  2547]
#  [ 2397 10103]]
# Training model with Embedding Dimension: 64, filters=16, kernel_size=7, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 8s 21ms/step - loss: 0.5024 - accuracy: 0.7306 - val_loss: 0.4152 - val_accuracy: 0.8044
# Epoch 2/5
# 313/313 [==============================] - 6s 20ms/step - loss: 0.2639 - accuracy: 0.8943 - val_loss: 0.4259 - val_accuracy: 0.8108
# Epoch 3/5
# 313/313 [==============================] - 7s 23ms/step - loss: 0.0779 - accuracy: 0.9760 - val_loss: 0.6352 - val_accuracy: 0.7988
# Epoch 4/5
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0090 - accuracy: 0.9986 - val_loss: 0.8258 - val_accuracy: 0.8000
# Epoch 5/5
# 313/313 [==============================] - 7s 23ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.9058 - val_accuracy: 0.8054
# 782/782 [==============================] - 2s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.79640
# Precision: 0.79593
# Recall: 0.79720
# F1 Score: 0.79656
# Confusion Matrix:
# [[9945 2555]
#  [2535 9965]]
# Training model with Embedding Dimension: 64, filters=16, kernel_size=7, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 9s 27ms/step - loss: 0.5219 - accuracy: 0.7139 - val_loss: 0.4055 - val_accuracy: 0.8100
# Epoch 2/5
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2748 - accuracy: 0.8873 - val_loss: 0.4290 - val_accuracy: 0.8014
# Epoch 3/5
# 313/313 [==============================] - 9s 27ms/step - loss: 0.0927 - accuracy: 0.9722 - val_loss: 0.5859 - val_accuracy: 0.7934
# Epoch 4/5
# 313/313 [==============================] - 7s 21ms/step - loss: 0.0109 - accuracy: 0.9989 - val_loss: 0.7708 - val_accuracy: 0.7922
# Epoch 5/5
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.8615 - val_accuracy: 0.7992
# 782/782 [==============================] - 2s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.79980
# Precision: 0.80146
# Recall: 0.79704
# F1 Score: 0.79925
# Confusion Matrix:
# [[10032  2468]
#  [ 2537  9963]]
# Training model with Embedding Dimension: 64, filters=32, kernel_size=5, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 9s 25ms/step - loss: 0.5288 - accuracy: 0.7038 - val_loss: 0.3969 - val_accuracy: 0.8164
# Epoch 2/5
# 313/313 [==============================] - 6s 20ms/step - loss: 0.2744 - accuracy: 0.8892 - val_loss: 0.4445 - val_accuracy: 0.8014
# Epoch 3/5
# 313/313 [==============================] - 7s 24ms/step - loss: 0.0894 - accuracy: 0.9733 - val_loss: 0.5861 - val_accuracy: 0.7962
# Epoch 4/5
# 313/313 [==============================] - 6s 20ms/step - loss: 0.0105 - accuracy: 0.9984 - val_loss: 0.7879 - val_accuracy: 0.7952
# Epoch 5/5
# 313/313 [==============================] - 8s 25ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.8659 - val_accuracy: 0.7972
# 782/782 [==============================] - 2s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.80096
# Precision: 0.79800
# Recall: 0.80592
# F1 Score: 0.80194
# Confusion Matrix:
# [[ 9950  2550]
#  [ 2426 10074]]
# Training model with Embedding Dimension: 64, filters=32, kernel_size=5, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 8s 22ms/step - loss: 0.5123 - accuracy: 0.7269 - val_loss: 0.4159 - val_accuracy: 0.8068
# Epoch 2/5
# 313/313 [==============================] - 7s 24ms/step - loss: 0.2827 - accuracy: 0.8819 - val_loss: 0.4268 - val_accuracy: 0.8092
# Epoch 3/5
# 313/313 [==============================] - 7s 23ms/step - loss: 0.1100 - accuracy: 0.9659 - val_loss: 0.6018 - val_accuracy: 0.7860
# Epoch 4/5
# 313/313 [==============================] - 8s 25ms/step - loss: 0.0166 - accuracy: 0.9976 - val_loss: 0.7561 - val_accuracy: 0.7990
# Epoch 5/5
# 313/313 [==============================] - 8s 25ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.8873 - val_accuracy: 0.7934
# 782/782 [==============================] - 2s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.80312
# Precision: 0.77669
# Recall: 0.85088
# F1 Score: 0.81209
# Confusion Matrix:
# [[ 9442  3058]
#  [ 1864 10636]]
# Training model with Embedding Dimension: 64, filters=32, kernel_size=7, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 10s 29ms/step - loss: 0.5182 - accuracy: 0.7110 - val_loss: 0.4078 - val_accuracy: 0.8150
# Epoch 2/5
# 313/313 [==============================] - 8s 24ms/step - loss: 0.2790 - accuracy: 0.8855 - val_loss: 0.4376 - val_accuracy: 0.8100
# Epoch 3/5
# 313/313 [==============================] - 9s 29ms/step - loss: 0.0966 - accuracy: 0.9679 - val_loss: 0.5902 - val_accuracy: 0.7966
# Epoch 4/5
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0090 - accuracy: 0.9990 - val_loss: 0.8282 - val_accuracy: 0.7976
# Epoch 5/5
# 313/313 [==============================] - 8s 26ms/step - loss: 8.6335e-04 - accuracy: 1.0000 - val_loss: 0.9234 - val_accuracy: 0.8020
# 782/782 [==============================] - 4s 5ms/step
# Evaluation Metrics:
# Accuracy: 0.80124
# Precision: 0.79425
# Recall: 0.81312
# F1 Score: 0.80357
# Confusion Matrix:
# [[ 9867  2633]
#  [ 2336 10164]]
# Training model with Embedding Dimension: 64, filters=32, kernel_size=7, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 9s 25ms/step - loss: 0.5171 - accuracy: 0.7185 - val_loss: 0.4019 - val_accuracy: 0.8110
# Epoch 2/5
# 313/313 [==============================] - 9s 28ms/step - loss: 0.2696 - accuracy: 0.8900 - val_loss: 0.4234 - val_accuracy: 0.8068
# Epoch 3/5
# 313/313 [==============================] - 8s 27ms/step - loss: 0.0856 - accuracy: 0.9734 - val_loss: 0.6015 - val_accuracy: 0.7920
# Epoch 4/5
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0100 - accuracy: 0.9991 - val_loss: 0.7881 - val_accuracy: 0.7968
# Epoch 5/5
# 313/313 [==============================] - 9s 28ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.8700 - val_accuracy: 0.7936
# 782/782 [==============================] - 2s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.80184
# Precision: 0.79930
# Recall: 0.80608
# F1 Score: 0.80268
# Confusion Matrix:
# [[ 9970  2530]
#  [ 2424 10076]]
# Training model with Embedding Dimension: 100, filters=16, kernel_size=5, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 10s 28ms/step - loss: 0.5045 - accuracy: 0.7286 - val_loss: 0.4226 - val_accuracy: 0.7970
# Epoch 2/5
# 313/313 [==============================] - 7s 23ms/step - loss: 0.2504 - accuracy: 0.8996 - val_loss: 0.4668 - val_accuracy: 0.7940
# Epoch 3/5
# 313/313 [==============================] - 8s 27ms/step - loss: 0.0539 - accuracy: 0.9850 - val_loss: 0.6620 - val_accuracy: 0.7966
# Epoch 4/5
# 313/313 [==============================] - 7s 23ms/step - loss: 0.0063 - accuracy: 0.9992 - val_loss: 0.8128 - val_accuracy: 0.7984
# Epoch 5/5
# 313/313 [==============================] - 9s 28ms/step - loss: 7.1371e-04 - accuracy: 1.0000 - val_loss: 0.8867 - val_accuracy: 0.7986
# 782/782 [==============================] - 2s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.80132
# Precision: 0.79277
# Recall: 0.81592
# F1 Score: 0.80418
# Confusion Matrix:
# [[ 9834  2666]
#  [ 2301 10199]]
# Training model with Embedding Dimension: 100, filters=16, kernel_size=5, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 9s 27ms/step - loss: 0.5135 - accuracy: 0.7250 - val_loss: 0.4004 - val_accuracy: 0.8128
# Epoch 2/5
# 313/313 [==============================] - 7s 23ms/step - loss: 0.2609 - accuracy: 0.8949 - val_loss: 0.4474 - val_accuracy: 0.8002
# Epoch 3/5
# 313/313 [==============================] - 8s 27ms/step - loss: 0.0692 - accuracy: 0.9799 - val_loss: 0.5980 - val_accuracy: 0.7918
# Epoch 4/5
# 313/313 [==============================] - 7s 22ms/step - loss: 0.0072 - accuracy: 0.9994 - val_loss: 0.7572 - val_accuracy: 0.7966
# Epoch 5/5
# 313/313 [==============================] - 8s 26ms/step - loss: 9.7015e-04 - accuracy: 1.0000 - val_loss: 0.8394 - val_accuracy: 0.7988
# 782/782 [==============================] - 2s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.80560
# Precision: 0.80050
# Recall: 0.81408
# F1 Score: 0.80723
# Confusion Matrix:
# [[ 9964  2536]
#  [ 2324 10176]]
# Training model with Embedding Dimension: 100, filters=16, kernel_size=7, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 11s 30ms/step - loss: 0.5055 - accuracy: 0.7281 - val_loss: 0.3939 - val_accuracy: 0.8152
# Epoch 2/5
# 313/313 [==============================] - 8s 25ms/step - loss: 0.2522 - accuracy: 0.8989 - val_loss: 0.4424 - val_accuracy: 0.8008
# Epoch 3/5
# 313/313 [==============================] - 9s 28ms/step - loss: 0.0574 - accuracy: 0.9827 - val_loss: 0.6580 - val_accuracy: 0.7926
# Epoch 4/5
# 313/313 [==============================] - 9s 30ms/step - loss: 0.0057 - accuracy: 0.9995 - val_loss: 0.8302 - val_accuracy: 0.7996
# Epoch 5/5
# 313/313 [==============================] - 8s 24ms/step - loss: 6.2701e-04 - accuracy: 1.0000 - val_loss: 0.8970 - val_accuracy: 0.7990
# 782/782 [==============================] - 3s 4ms/step
# Evaluation Metrics:
# Accuracy: 0.80104
# Precision: 0.79941
# Recall: 0.80376
# F1 Score: 0.80158
# Confusion Matrix:
# [[ 9979  2521]
#  [ 2453 10047]]
# Training model with Embedding Dimension: 100, filters=16, kernel_size=7, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 11s 33ms/step - loss: 0.5152 - accuracy: 0.7179 - val_loss: 0.3979 - val_accuracy: 0.8160
# Epoch 2/5
# 313/313 [==============================] - 9s 28ms/step - loss: 0.2599 - accuracy: 0.8931 - val_loss: 0.4394 - val_accuracy: 0.7996
# Epoch 3/5
# 313/313 [==============================] - 10s 32ms/step - loss: 0.0622 - accuracy: 0.9829 - val_loss: 0.6263 - val_accuracy: 0.7916
# Epoch 4/5
# 313/313 [==============================] - 10s 33ms/step - loss: 0.0054 - accuracy: 0.9995 - val_loss: 0.7985 - val_accuracy: 0.7962
# Epoch 5/5
# 313/313 [==============================] - 9s 28ms/step - loss: 7.3856e-04 - accuracy: 1.0000 - val_loss: 0.8819 - val_accuracy: 0.7990
# 782/782 [==============================] - 4s 5ms/step
# Evaluation Metrics:
# Accuracy: 0.80604
# Precision: 0.80646
# Recall: 0.80536
# F1 Score: 0.80591
# Confusion Matrix:
# [[10084  2416]
#  [ 2433 10067]]
# Training model with Embedding Dimension: 100, filters=32, kernel_size=5, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 10s 29ms/step - loss: 0.4956 - accuracy: 0.7336 - val_loss: 0.4121 - val_accuracy: 0.8078
# Epoch 2/5
# 313/313 [==============================] - 10s 31ms/step - loss: 0.2557 - accuracy: 0.8958 - val_loss: 0.4703 - val_accuracy: 0.7952
# Epoch 3/5
# 313/313 [==============================] - 10s 33ms/step - loss: 0.0710 - accuracy: 0.9783 - val_loss: 0.6220 - val_accuracy: 0.7994
# Epoch 4/5
# 313/313 [==============================] - 9s 29ms/step - loss: 0.0071 - accuracy: 0.9990 - val_loss: 0.8212 - val_accuracy: 0.8054
# Epoch 5/5
# 313/313 [==============================] - 10s 32ms/step - loss: 7.3027e-04 - accuracy: 1.0000 - val_loss: 0.9059 - val_accuracy: 0.8032
# 782/782 [==============================] - 3s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.80552
# Precision: 0.80484
# Recall: 0.80664
# F1 Score: 0.80574
# Confusion Matrix:
# [[10055  2445]
#  [ 2417 10083]]
# Training model with Embedding Dimension: 100, filters=32, kernel_size=5, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 11s 32ms/step - loss: 0.5227 - accuracy: 0.7132 - val_loss: 0.3959 - val_accuracy: 0.8110
# Epoch 2/5
# 313/313 [==============================] - 11s 34ms/step - loss: 0.2681 - accuracy: 0.8914 - val_loss: 0.4179 - val_accuracy: 0.8092
# Epoch 3/5
# 313/313 [==============================] - 11s 34ms/step - loss: 0.0697 - accuracy: 0.9815 - val_loss: 0.5858 - val_accuracy: 0.7988
# Epoch 4/5
# 313/313 [==============================] - 10s 31ms/step - loss: 0.0067 - accuracy: 0.9997 - val_loss: 0.7392 - val_accuracy: 0.8050
# Epoch 5/5
# 313/313 [==============================] - 10s 32ms/step - loss: 8.7393e-04 - accuracy: 1.0000 - val_loss: 0.8120 - val_accuracy: 0.8046
# 782/782 [==============================] - 3s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.80396
# Precision: 0.79742
# Recall: 0.81496
# F1 Score: 0.80609
# Confusion Matrix:
# [[ 9912  2588]
#  [ 2313 10187]]
# Training model with Embedding Dimension: 100, filters=32, kernel_size=7, maxpool=False
# Epoch 1/5
# 313/313 [==============================] - 13s 37ms/step - loss: 0.4924 - accuracy: 0.7354 - val_loss: 0.3996 - val_accuracy: 0.8144
# Epoch 2/5
# 313/313 [==============================] - 10s 33ms/step - loss: 0.2455 - accuracy: 0.9011 - val_loss: 0.4752 - val_accuracy: 0.8012
# Epoch 3/5
# 313/313 [==============================] - 12s 38ms/step - loss: 0.0521 - accuracy: 0.9848 - val_loss: 0.6562 - val_accuracy: 0.7890
# Epoch 4/5
# 313/313 [==============================] - 12s 38ms/step - loss: 0.0050 - accuracy: 0.9995 - val_loss: 0.8422 - val_accuracy: 0.8000
# Epoch 5/5
# 313/313 [==============================] - 11s 37ms/step - loss: 5.2772e-04 - accuracy: 1.0000 - val_loss: 0.9329 - val_accuracy: 0.8036
# 782/782 [==============================] - 3s 4ms/step
# Evaluation Metrics:
# Accuracy: 0.80364
# Precision: 0.80357
# Recall: 0.80376
# F1 Score: 0.80366
# Confusion Matrix:
# [[10044  2456]
#  [ 2453 10047]]
# Training model with Embedding Dimension: 100, filters=32, kernel_size=7, maxpool=True
# Epoch 1/5
# 313/313 [==============================] - 13s 40ms/step - loss: 0.4965 - accuracy: 0.7399 - val_loss: 0.4025 - val_accuracy: 0.8142
# Epoch 2/5
# 313/313 [==============================] - 12s 39ms/step - loss: 0.2495 - accuracy: 0.9003 - val_loss: 0.4423 - val_accuracy: 0.8092
# Epoch 3/5
# 313/313 [==============================] - 12s 37ms/step - loss: 0.0597 - accuracy: 0.9844 - val_loss: 0.6517 - val_accuracy: 0.7934
# Epoch 4/5
# 313/313 [==============================] - 11s 36ms/step - loss: 0.0055 - accuracy: 0.9995 - val_loss: 0.8080 - val_accuracy: 0.7952
# Epoch 5/5
# 313/313 [==============================] - 12s 37ms/step - loss: 7.1955e-04 - accuracy: 1.0000 - val_loss: 0.8939 - val_accuracy: 0.7960
# 782/782 [==============================] - 5s 6ms/step
# Evaluation Metrics:
# Accuracy: 0.80164
# Precision: 0.79932
# Recall: 0.80552
# F1 Score: 0.80241
# Confusion Matrix:
# [[ 9972  2528]
#  [ 2431 10069]]

# %% [markdown]
# **Persian Text Sentiment Dataset**

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.19.2-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests>=2.32.1 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.3 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, requests, dill, multiprocess, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# Successfully installed datasets-2.19.2 dill-0.3.8 multiprocess-0.70.16 requests-2.32.3 xxhash-3.4.1

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Flatten, Conv1D, MaxPooling1D
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import numpy as np
from datasets import load_dataset

def preprocess_persian_text_sentiment(dataset):
    texts = dataset['train']['text']
    labels = dataset['train']['label']
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(texts)
    sequences = tokenizer.texts_to_sequences(texts)
    word_index = tokenizer.word_index
    max_words = len(word_index) + 1
    X = pad_sequences(sequences, maxlen=50)
    y = np.array(labels)
    return X, y, max_words

def train_model_with_cnn(embedding_dim, X_train, y_train, X_test, y_test, max_words, filters, kernel_size, use_maxpool):
    model = Sequential()
    model.add(Embedding(max_words, embedding_dim, input_length=50))
    model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='relu'))
    if use_maxpool:
        model.add(MaxPooling1D())
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.fit(X_train, y_train, epochs=5, batch_size=64, validation_split=0.2)

    y_pred = (model.predict(X_test) > 0.5).astype("int32")

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    print("Evaluation Metrics:")
    print(f"Accuracy: {accuracy:.5f}")
    print(f"Precision: {precision:.5f}")
    print(f"Recall: {recall:.5f}")
    print(f"F1 Score: {f1:.5f}")
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))

# Load Persian Text Sentiment dataset
persian_dataset = load_dataset("SeyedAli/Persian-Text-Sentiment")
X_persian, y_persian, max_words_persian = preprocess_persian_text_sentiment(persian_dataset)

embedding_dim = 100
configs = [
    (16, 5, False), (16, 5, True), (16, 7, False), (16, 7, True),
    (32, 5, False), (32, 5, True), (32, 7, False), (32, 7, True)
]

for filters, kernel_size, use_maxpool in configs:
    print(f"Training model with Embedding Dimension: {embedding_dim}, filters={filters}, kernel_size={kernel_size}, maxpool={use_maxpool}")
    train_model_with_cnn(embedding_dim, X_persian, y_persian, X_persian, y_persian, max_words_persian, filters, kernel_size, use_maxpool)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/524 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.22M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/55852 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/13964 [00:00<?, ? examples/s]
# Training model with Embedding Dimension: 100, filters=16, kernel_size=5, maxpool=False
# Epoch 1/5
# 699/699 [==============================] - 41s 52ms/step - loss: 0.3846 - accuracy: 0.8250 - val_loss: 0.3457 - val_accuracy: 0.8507
# Epoch 2/5
# 699/699 [==============================] - 8s 12ms/step - loss: 0.2613 - accuracy: 0.8939 - val_loss: 0.3633 - val_accuracy: 0.8489
# Epoch 3/5
# 699/699 [==============================] - 7s 10ms/step - loss: 0.1653 - accuracy: 0.9367 - val_loss: 0.4405 - val_accuracy: 0.8258
# Epoch 4/5
# 699/699 [==============================] - 5s 8ms/step - loss: 0.0901 - accuracy: 0.9681 - val_loss: 0.6024 - val_accuracy: 0.8185
# Epoch 5/5
# 699/699 [==============================] - 6s 8ms/step - loss: 0.0546 - accuracy: 0.9811 - val_loss: 0.7851 - val_accuracy: 0.8251
# 1746/1746 [==============================] - 3s 2ms/step
# Evaluation Metrics:
# Accuracy: 0.95655
# Precision: 0.95866
# Recall: 0.95424
# F1 Score: 0.95645
# Confusion Matrix:
# [[26777  1149]
#  [ 1278 26648]]
# Training model with Embedding Dimension: 100, filters=16, kernel_size=5, maxpool=True
# Epoch 1/5
# 699/699 [==============================] - 26s 36ms/step - loss: 0.3811 - accuracy: 0.8261 - val_loss: 0.3424 - val_accuracy: 0.8550
# Epoch 2/5
# 699/699 [==============================] - 8s 11ms/step - loss: 0.2599 - accuracy: 0.8962 - val_loss: 0.3624 - val_accuracy: 0.8444
# Epoch 3/5
# 699/699 [==============================] - 5s 7ms/step - loss: 0.1668 - accuracy: 0.9369 - val_loss: 0.4243 - val_accuracy: 0.8365
# Epoch 4/5
# 699/699 [==============================] - 5s 7ms/step - loss: 0.0895 - accuracy: 0.9684 - val_loss: 0.5569 - val_accuracy: 0.8206
# Epoch 5/5
# 699/699 [==============================] - 5s 7ms/step - loss: 0.0528 - accuracy: 0.9820 - val_loss: 0.7342 - val_accuracy: 0.8187
# 1746/1746 [==============================] - 3s 2ms/step
# Evaluation Metrics:
# Accuracy: 0.95621
# Precision: 0.95387
# Recall: 0.95878
# F1 Score: 0.95632
# Confusion Matrix:
# [[26631  1295]
#  [ 1151 26775]]
# Training model with Embedding Dimension: 100, filters=16, kernel_size=7, maxpool=False
# Epoch 1/5
# 699/699 [==============================] - 25s 34ms/step - loss: 0.3815 - accuracy: 0.8274 - val_loss: 0.3474 - val_accuracy: 0.8526
# Epoch 2/5
# 699/699 [==============================] - 9s 12ms/step - loss: 0.2596 - accuracy: 0.8937 - val_loss: 0.3623 - val_accuracy: 0.8493
# Epoch 3/5
# 699/699 [==============================] - 5s 8ms/step - loss: 0.1608 - accuracy: 0.9386 - val_loss: 0.4844 - val_accuracy: 0.8354
# Epoch 4/5
# 699/699 [==============================] - 6s 9ms/step - loss: 0.0864 - accuracy: 0.9690 - val_loss: 0.6190 - val_accuracy: 0.8225
# Epoch 5/5
# 699/699 [==============================] - 5s 7ms/step - loss: 0.0524 - accuracy: 0.9808 - val_loss: 0.8024 - val_accuracy: 0.8251
# 1746/1746 [==============================] - 3s 2ms/step
# Evaluation Metrics:
# Accuracy: 0.95651
# Precision: 0.96246
# Recall: 0.95008
# F1 Score: 0.95623
# Confusion Matrix:
# [[26891  1035]
#  [ 1394 26532]]
# Training model with Embedding Dimension: 100, filters=16, kernel_size=7, maxpool=True
# Epoch 1/5
# 699/699 [==============================] - 24s 33ms/step - loss: 0.3814 - accuracy: 0.8282 - val_loss: 0.3426 - val_accuracy: 0.8597
# Epoch 2/5
# 699/699 [==============================] - 7s 10ms/step - loss: 0.2570 - accuracy: 0.8964 - val_loss: 0.3651 - val_accuracy: 0.8503
# Epoch 3/5
# 699/699 [==============================] - 5s 8ms/step - loss: 0.1568 - accuracy: 0.9412 - val_loss: 0.4545 - val_accuracy: 0.8364
# Epoch 4/5
# 699/699 [==============================] - 6s 8ms/step - loss: 0.0839 - accuracy: 0.9703 - val_loss: 0.6026 - val_accuracy: 0.8312
# Epoch 5/5
# 699/699 [==============================] - 6s 8ms/step - loss: 0.0490 - accuracy: 0.9828 - val_loss: 0.7456 - val_accuracy: 0.8200
# 1746/1746 [==============================] - 4s 2ms/step
# Evaluation Metrics:
# Accuracy: 0.95710
# Precision: 0.95940
# Recall: 0.95459
# F1 Score: 0.95699
# Confusion Matrix:
# [[26798  1128]
#  [ 1268 26658]]
# Training model with Embedding Dimension: 100, filters=32, kernel_size=5, maxpool=False
# Epoch 1/5
# 699/699 [==============================] - 24s 33ms/step - loss: 0.3763 - accuracy: 0.8332 - val_loss: 0.3422 - val_accuracy: 0.8540
# Epoch 2/5
# 699/699 [==============================] - 8s 12ms/step - loss: 0.2590 - accuracy: 0.8944 - val_loss: 0.3732 - val_accuracy: 0.8487
# Epoch 3/5
# 699/699 [==============================] - 7s 10ms/step - loss: 0.1560 - accuracy: 0.9402 - val_loss: 0.4782 - val_accuracy: 0.8326
# Epoch 4/5
# 699/699 [==============================] - 5s 7ms/step - loss: 0.0824 - accuracy: 0.9700 - val_loss: 0.6216 - val_accuracy: 0.8227
# Epoch 5/5
# 699/699 [==============================] - 6s 9ms/step - loss: 0.0500 - accuracy: 0.9816 - val_loss: 0.8170 - val_accuracy: 0.8202
# 1746/1746 [==============================] - 4s 2ms/step
# Evaluation Metrics:
# Accuracy: 0.95613
# Precision: 0.95758
# Recall: 0.95456
# F1 Score: 0.95606
# Confusion Matrix:
# [[26745  1181]
#  [ 1269 26657]]
# Training model with Embedding Dimension: 100, filters=32, kernel_size=5, maxpool=True
# Epoch 1/5
# 699/699 [==============================] - 26s 36ms/step - loss: 0.3794 - accuracy: 0.8277 - val_loss: 0.3402 - val_accuracy: 0.8561
# Epoch 2/5
# 699/699 [==============================] - 6s 9ms/step - loss: 0.2594 - accuracy: 0.8953 - val_loss: 0.3651 - val_accuracy: 0.8468
# Epoch 3/5
# 699/699 [==============================] - 6s 9ms/step - loss: 0.1617 - accuracy: 0.9402 - val_loss: 0.4538 - val_accuracy: 0.8371
# Epoch 4/5
# 699/699 [==============================] - 5s 7ms/step - loss: 0.0847 - accuracy: 0.9704 - val_loss: 0.5981 - val_accuracy: 0.8274
# Epoch 5/5
# 699/699 [==============================] - 5s 7ms/step - loss: 0.0494 - accuracy: 0.9823 - val_loss: 0.7413 - val_accuracy: 0.8173
# 1746/1746 [==============================] - 3s 2ms/step
# Evaluation Metrics:
# Accuracy: 0.95630
# Precision: 0.95904
# Recall: 0.95331
# F1 Score: 0.95616
# Confusion Matrix:
# [[26789  1137]
#  [ 1304 26622]]
# Training model with Embedding Dimension: 100, filters=32, kernel_size=7, maxpool=False
# Epoch 1/5
# 699/699 [==============================] - 26s 35ms/step - loss: 0.3785 - accuracy: 0.8284 - val_loss: 0.3420 - val_accuracy: 0.8559
# Epoch 2/5
# 699/699 [==============================] - 6s 9ms/step - loss: 0.2528 - accuracy: 0.8991 - val_loss: 0.3749 - val_accuracy: 0.8453
# Epoch 3/5
# 699/699 [==============================] - 7s 9ms/step - loss: 0.1442 - accuracy: 0.9458 - val_loss: 0.4934 - val_accuracy: 0.8295
# Epoch 4/5
# 699/699 [==============================] - 4s 6ms/step - loss: 0.0773 - accuracy: 0.9708 - val_loss: 0.6655 - val_accuracy: 0.8279
# Epoch 5/5
# 699/699 [==============================] - 6s 8ms/step - loss: 0.0479 - accuracy: 0.9823 - val_loss: 0.9208 - val_accuracy: 0.8257
# 1746/1746 [==============================] - 3s 2ms/step
# Evaluation Metrics:
# Accuracy: 0.95660
# Precision: 0.96577
# Recall: 0.94675
# F1 Score: 0.95617
# Confusion Matrix:
# [[26989   937]
#  [ 1487 26439]]
# Training model with Embedding Dimension: 100, filters=32, kernel_size=7, maxpool=True
# Epoch 1/5
# 699/699 [==============================] - 25s 35ms/step - loss: 0.3803 - accuracy: 0.8282 - val_loss: 0.3453 - val_accuracy: 0.8544
# Epoch 2/5
# 699/699 [==============================] - 9s 12ms/step - loss: 0.2574 - accuracy: 0.8960 - val_loss: 0.3593 - val_accuracy: 0.8480
# Epoch 3/5
# 699/699 [==============================] - 5s 8ms/step - loss: 0.1524 - accuracy: 0.9426 - val_loss: 0.4492 - val_accuracy: 0.8293
# Epoch 4/5
# 699/699 [==============================] - 6s 8ms/step - loss: 0.0763 - accuracy: 0.9724 - val_loss: 0.6113 - val_accuracy: 0.8255
# Epoch 5/5
# 699/699 [==============================] - 5s 7ms/step - loss: 0.0454 - accuracy: 0.9845 - val_loss: 0.8075 - val_accuracy: 0.8224
# 1746/1746 [==============================] - 3s 2ms/step
# Evaluation Metrics:
# Accuracy: 0.95800
# Precision: 0.96692
# Recall: 0.94844
# F1 Score: 0.95759
# Confusion Matrix:
# [[27020   906]
#  [ 1440 26486]]

# %% [markdown]
# **Persian News Dataset**

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense, Conv1D, MaxPooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from datasets import load_dataset
from sklearn.preprocessing import LabelEncoder

def preprocess_persian_news_dataset(dataset, maxlen=50):
    texts = []
    labels = []
    for doc in dataset:
        if len(doc['title']) > 0 and len(doc['category']) > 0:
            texts.append(doc['text'])
            labels.append(doc['category'])

    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(texts)
    sequences = tokenizer.texts_to_sequences(texts)
    word_index = tokenizer.word_index
    max_words = len(word_index) + 1
    X = pad_sequences(sequences, maxlen=maxlen)

    label_encoder = LabelEncoder()
    y = label_encoder.fit_transform(labels)

    return X, y, max_words

dataset = load_dataset("saied/persian_news_dataset", split="train", streaming=True)

docs = []
document_count = 40000
counter = 0
skip_counter = 0

for doc in dataset:
    if len(doc['title']) == 0 or len(doc['category']) == 0:
        skip_counter += 1
        if skip_counter % 10000 == 0:
            print(f'{skip_counter} skipped')
        continue
    docs.append(doc)
    counter += 1
    if counter == document_count:
        break

print(f"Number of documents processed: {len(docs)}")

not_proccess_x = [doc['text'] for doc in docs]
not_proccess_y = [doc['category'] for doc in docs]

max_words_news = 10000
max_length_news = 50

tokenizer = Tokenizer(num_words=max_words_news, oov_token="<OOV>")
tokenizer.fit_on_texts(not_proccess_x)

x_news = tokenizer.texts_to_sequences(not_proccess_x)
x_news = pad_sequences(x_news, maxlen=max_length_news)

label_encoder = LabelEncoder()
y_news = label_encoder.fit_transform(not_proccess_y)

x_train_news, x_test_news, y_train_news, y_test_news = train_test_split(x_news, y_news, test_size=0.3, random_state=42)
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1491: FutureWarning: The repository for saied/persian_news_dataset contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/saied/persian_news_dataset
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 10000 skipped
# 20000 skipped
# 30000 skipped
# 40000 skipped
# 50000 skipped
# 60000 skipped
# 70000 skipped
# 80000 skipped
# 90000 skipped
# 100000 skipped
# 110000 skipped
# 120000 skipped
# 130000 skipped
# 140000 skipped
# 150000 skipped
# 160000 skipped
# 170000 skipped
# 180000 skipped
# 190000 skipped
# 200000 skipped
# 210000 skipped
# 220000 skipped
# 230000 skipped
# 240000 skipped
# Number of documents processed: 40000

# %%
embedding_dim = 100
configs = [
    (16, 5, False), (16, 5, True), (16, 7, False), (16, 7, True),
    (32, 5, False), (32, 5, True), (32, 7, False), (32, 7, True)
]

for filters, kernel_size, use_maxpool in configs:
    print(f"Training model with Embedding Dimension: {embedding_dim}, filters={filters}, kernel_size={kernel_size}, maxpool={use_maxpool}")
    model = Sequential([
        Embedding(input_dim=max_words_news, output_dim=embedding_dim, input_length=max_length_news),
        Conv1D(filters=filters, kernel_size=kernel_size, activation='relu'),
        MaxPooling1D() if use_maxpool else Flatten(),
        Flatten(),
        Dense(64, activation="relu"),
        Dense(len(set(y_news)), activation="softmax"),
    ])

    model.compile(optimizer="rmsprop", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    model.summary()
    model.fit(x_train_news, y_train_news, epochs=5, batch_size=512)

    test_loss, test_acc = model.evaluate(x_test_news, y_test_news)
    print(f"test_acc: {test_acc} \t test_loss: {test_loss}")

    y_pred_probs = model.predict(x_test_news)
    y_pred = np.argmax(y_pred_probs, axis=1)

    cm = confusion_matrix(y_test_news, y_pred)

    print("Confusion Matrix:")
    print(cm)

    unique_categories = label_encoder.classes_

    for i, category in enumerate(unique_categories):
        tp = cm[i, i]
        fp = cm[:, i].sum() - tp
        fn = cm[i, :].sum() - tp
        tn = cm.sum() - (tp + fp + fn)

        precision = tp / (tp + fp) if tp + fp > 0 else 0
        recall = tp / (tp + fn) if tp + fn > 0 else 0
        accuracy = (tp + tn) / cm.sum() if cm.sum() > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        print(f"Category: {category}")
        print(f"Precision: {precision:.5f}")
        print(f"Recall: {recall:.5f}")
        print(f"Accuracy: {accuracy:.5f}")
        print(f"F1 Score: {f1_score:.5f}")
        print("--------------------------------------")
# Out:
# Training model with Embedding Dimension: 100, filters=16, kernel_size=5, maxpool=False
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 50, 100)           1000000
#
#  conv1d_8 (Conv1D)           (None, 46, 16)            8016
#
#  flatten_8 (Flatten)         (None, 736)               0
#
#  flatten_9 (Flatten)         (None, 736)               0
#
#  dense_16 (Dense)            (None, 64)                47168
#
#  dense_17 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 1055574 (4.03 MB)
# Trainable params: 1055574 (4.03 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/5
# 55/55 [==============================] - 10s 160ms/step - loss: 1.3209 - accuracy: 0.5021
# Epoch 2/5
# 55/55 [==============================] - 6s 109ms/step - loss: 0.2350 - accuracy: 0.9638
# Epoch 3/5
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0206 - accuracy: 0.9964
# Epoch 4/5
# 55/55 [==============================] - 2s 28ms/step - loss: 0.0074 - accuracy: 0.9983
# Epoch 5/5
# 55/55 [==============================] - 2s 32ms/step - loss: 0.0038 - accuracy: 0.9993
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0098 - accuracy: 0.9967
# test_acc: 0.996666669845581 	 test_loss: 0.009793885052204132
# 375/375 [==============================] - 1s 2ms/step
# Confusion Matrix:
# [[2392    0    0    0    5    1]
#  [   0 2654    0    0    0    0]
#  [   7    0 2139    0    4    9]
#  [   0    0    0 2367    0    1]
#  [   2    0    1    0 1248    2]
#  [   2    0    0    0    6 1160]]
# Category: اقتصاد
# Precision: 0.99542
# Recall: 0.99750
# Accuracy: 0.99858
# F1 Score: 0.99646
# --------------------------------------
# Category: جامعه
# Precision: 1.00000
# Recall: 1.00000
# Accuracy: 1.00000
# F1 Score: 1.00000
# --------------------------------------
# Category: جهان
# Precision: 0.99953
# Recall: 0.99074
# Accuracy: 0.99825
# F1 Score: 0.99512
# --------------------------------------
# Category: سیاست
# Precision: 1.00000
# Recall: 0.99958
# Accuracy: 0.99992
# F1 Score: 0.99979
# --------------------------------------
# Category: فرهنگ
# Precision: 0.98812
# Recall: 0.99601
# Accuracy: 0.99833
# F1 Score: 0.99205
# --------------------------------------
# Category: ورزش
# Precision: 0.98892
# Recall: 0.99315
# Accuracy: 0.99825
# F1 Score: 0.99103
# --------------------------------------
# Training model with Embedding Dimension: 100, filters=16, kernel_size=5, maxpool=True
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 50, 100)           1000000
#
#  conv1d_9 (Conv1D)           (None, 46, 16)            8016
#
#  max_pooling1d_4 (MaxPoolin  (None, 23, 16)            0
#  g1D)
#
#  flatten_10 (Flatten)        (None, 368)               0
#
#  dense_18 (Dense)            (None, 64)                23616
#
#  dense_19 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 1032022 (3.94 MB)
# Trainable params: 1032022 (3.94 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/5
# 55/55 [==============================] - 4s 59ms/step - loss: 1.3121 - accuracy: 0.5753
# Epoch 2/5
# 55/55 [==============================] - 2s 40ms/step - loss: 0.2414 - accuracy: 0.9425
# Epoch 3/5
# 55/55 [==============================] - 2s 42ms/step - loss: 0.0341 - accuracy: 0.9948
# Epoch 4/5
# 55/55 [==============================] - 3s 48ms/step - loss: 0.0090 - accuracy: 0.9985
# Epoch 5/5
# 55/55 [==============================] - 1s 25ms/step - loss: 0.0043 - accuracy: 0.9993
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0091 - accuracy: 0.9975
# test_acc: 0.9975000023841858 	 test_loss: 0.009090635925531387
# 375/375 [==============================] - 1s 2ms/step
# Confusion Matrix:
# [[2387    0    3    0    1    7]
#  [   0 2654    0    0    0    0]
#  [   0    0 2149    0    1    9]
#  [   0    0    0 2368    0    0]
#  [   0    0    4    0 1246    3]
#  [   0    0    0    0    2 1166]]
# Category: اقتصاد
# Precision: 1.00000
# Recall: 0.99541
# Accuracy: 0.99908
# F1 Score: 0.99770
# --------------------------------------
# Category: جامعه
# Precision: 1.00000
# Recall: 1.00000
# Accuracy: 1.00000
# F1 Score: 1.00000
# --------------------------------------
# Category: جهان
# Precision: 0.99675
# Recall: 0.99537
# Accuracy: 0.99858
# F1 Score: 0.99606
# --------------------------------------
# Category: سیاست
# Precision: 1.00000
# Recall: 1.00000
# Accuracy: 1.00000
# F1 Score: 1.00000
# --------------------------------------
# Category: فرهنگ
# Precision: 0.99680
# Recall: 0.99441
# Accuracy: 0.99908
# F1 Score: 0.99561
# --------------------------------------
# Category: ورزش
# Precision: 0.98397
# Recall: 0.99829
# Accuracy: 0.99825
# F1 Score: 0.99108
# --------------------------------------
# Training model with Embedding Dimension: 100, filters=16, kernel_size=7, maxpool=False
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, 50, 100)           1000000
#
#  conv1d_10 (Conv1D)          (None, 44, 16)            11216
#
#  flatten_11 (Flatten)        (None, 704)               0
#
#  flatten_12 (Flatten)        (None, 704)               0
#
#  dense_20 (Dense)            (None, 64)                45120
#
#  dense_21 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 1056726 (4.03 MB)
# Trainable params: 1056726 (4.03 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/5
# 55/55 [==============================] - 5s 66ms/step - loss: 1.3095 - accuracy: 0.5136
# Epoch 2/5
# 55/55 [==============================] - 2s 43ms/step - loss: 0.2458 - accuracy: 0.9504
# Epoch 3/5
# 55/55 [==============================] - 2s 31ms/step - loss: 0.0240 - accuracy: 0.9970
# Epoch 4/5
# 55/55 [==============================] - 2s 38ms/step - loss: 0.0069 - accuracy: 0.9987
# Epoch 5/5
# 55/55 [==============================] - 2s 30ms/step - loss: 0.0035 - accuracy: 0.9995
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0077 - accuracy: 0.9977
# test_acc: 0.9976666569709778 	 test_loss: 0.0076907724142074585
# 375/375 [==============================] - 1s 2ms/step
# Confusion Matrix:
# [[2395    0    1    0    1    1]
#  [   0 2653    0    0    0    1]
#  [   4    0 2147    0    1    7]
#  [   0    0    0 2368    0    0]
#  [   2    0    2    0 1248    1]
#  [   1    0    0    0    6 1161]]
# Category: اقتصاد
# Precision: 0.99709
# Recall: 0.99875
# Accuracy: 0.99917
# F1 Score: 0.99792
# --------------------------------------
# Category: جامعه
# Precision: 1.00000
# Recall: 0.99962
# Accuracy: 0.99992
# F1 Score: 0.99981
# --------------------------------------
# Category: جهان
# Precision: 0.99860
# Recall: 0.99444
# Accuracy: 0.99875
# F1 Score: 0.99652
# --------------------------------------
# Category: سیاست
# Precision: 1.00000
# Recall: 1.00000
# Accuracy: 1.00000
# F1 Score: 1.00000
# --------------------------------------
# Category: فرهنگ
# Precision: 0.99363
# Recall: 0.99601
# Accuracy: 0.99892
# F1 Score: 0.99482
# --------------------------------------
# Category: ورزش
# Precision: 0.99146
# Recall: 0.99401
# Accuracy: 0.99858
# F1 Score: 0.99273
# --------------------------------------
# Training model with Embedding Dimension: 100, filters=16, kernel_size=7, maxpool=True
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_11 (Embedding)    (None, 50, 100)           1000000
#
#  conv1d_11 (Conv1D)          (None, 44, 16)            11216
#
#  max_pooling1d_5 (MaxPoolin  (None, 22, 16)            0
#  g1D)
#
#  flatten_13 (Flatten)        (None, 352)               0
#
#  dense_22 (Dense)            (None, 64)                22592
#
#  dense_23 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 1034198 (3.95 MB)
# Trainable params: 1034198 (3.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/5
# 55/55 [==============================] - 4s 58ms/step - loss: 1.3476 - accuracy: 0.5112
# Epoch 2/5
# 55/55 [==============================] - 2s 45ms/step - loss: 0.3487 - accuracy: 0.9231
# Epoch 3/5
# 55/55 [==============================] - 2s 40ms/step - loss: 0.0386 - accuracy: 0.9953
# Epoch 4/5
# 55/55 [==============================] - 2s 42ms/step - loss: 0.0097 - accuracy: 0.9981
# Epoch 5/5
# 55/55 [==============================] - 1s 23ms/step - loss: 0.0049 - accuracy: 0.9991
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0081 - accuracy: 0.9976
# test_acc: 0.9975833296775818 	 test_loss: 0.008080556988716125
# 375/375 [==============================] - 1s 2ms/step
# Confusion Matrix:
# [[2392    0    3    0    2    1]
#  [   0 2654    0    0    0    0]
#  [   2    0 2152    0    0    5]
#  [   0    0    0 2367    0    1]
#  [   1    0    3    0 1247    2]
#  [   0    0    5    0    4 1159]]
# Category: اقتصاد
# Precision: 0.99875
# Recall: 0.99750
# Accuracy: 0.99925
# F1 Score: 0.99812
# --------------------------------------
# Category: جامعه
# Precision: 1.00000
# Recall: 1.00000
# Accuracy: 1.00000
# F1 Score: 1.00000
# --------------------------------------
# Category: جهان
# Precision: 0.99491
# Recall: 0.99676
# Accuracy: 0.99850
# F1 Score: 0.99584
# --------------------------------------
# Category: سیاست
# Precision: 1.00000
# Recall: 0.99958
# Accuracy: 0.99992
# F1 Score: 0.99979
# --------------------------------------
# Category: فرهنگ
# Precision: 0.99521
# Recall: 0.99521
# Accuracy: 0.99900
# F1 Score: 0.99521
# --------------------------------------
# Category: ورزش
# Precision: 0.99229
# Recall: 0.99229
# Accuracy: 0.99850
# F1 Score: 0.99229
# --------------------------------------
# Training model with Embedding Dimension: 100, filters=32, kernel_size=5, maxpool=False
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_12 (Embedding)    (None, 50, 100)           1000000
#
#  conv1d_12 (Conv1D)          (None, 46, 32)            16032
#
#  flatten_14 (Flatten)        (None, 1472)              0
#
#  flatten_15 (Flatten)        (None, 1472)              0
#
#  dense_24 (Dense)            (None, 64)                94272
#
#  dense_25 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 1110694 (4.24 MB)
# Trainable params: 1110694 (4.24 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/5
# 55/55 [==============================] - 5s 63ms/step - loss: 1.1949 - accuracy: 0.5764
# Epoch 2/5
# 55/55 [==============================] - 2s 42ms/step - loss: 0.1409 - accuracy: 0.9705
# Epoch 3/5
# 55/55 [==============================] - 2s 36ms/step - loss: 0.0179 - accuracy: 0.9967
# Epoch 4/5
# 55/55 [==============================] - 2s 34ms/step - loss: 0.0062 - accuracy: 0.9991
# Epoch 5/5
# 55/55 [==============================] - 1s 22ms/step - loss: 0.0032 - accuracy: 0.9996
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0070 - accuracy: 0.9975
# test_acc: 0.9975000023841858 	 test_loss: 0.007023075129836798
# 375/375 [==============================] - 1s 2ms/step
# Confusion Matrix:
# [[2394    0    1    0    2    1]
#  [   0 2654    0    0    0    0]
#  [   6    0 2148    0    3    2]
#  [   0    0    0 2367    0    1]
#  [   1    0    2    0 1248    2]
#  [   4    0    1    0    4 1159]]
# Category: اقتصاد
# Precision: 0.99543
# Recall: 0.99833
# Accuracy: 0.99875
# F1 Score: 0.99688
# --------------------------------------
# Category: جامعه
# Precision: 1.00000
# Recall: 1.00000
# Accuracy: 1.00000
# F1 Score: 1.00000
# --------------------------------------
# Category: جهان
# Precision: 0.99814
# Recall: 0.99491
# Accuracy: 0.99875
# F1 Score: 0.99652
# --------------------------------------
# Category: سیاست
# Precision: 1.00000
# Recall: 0.99958
# Accuracy: 0.99992
# F1 Score: 0.99979
# --------------------------------------
# Category: فرهنگ
# Precision: 0.99284
# Recall: 0.99601
# Accuracy: 0.99883
# F1 Score: 0.99442
# --------------------------------------
# Category: ورزش
# Precision: 0.99485
# Recall: 0.99229
# Accuracy: 0.99875
# F1 Score: 0.99357
# --------------------------------------
# Training model with Embedding Dimension: 100, filters=32, kernel_size=5, maxpool=True
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_13 (Embedding)    (None, 50, 100)           1000000
#
#  conv1d_13 (Conv1D)          (None, 46, 32)            16032
#
#  max_pooling1d_6 (MaxPoolin  (None, 23, 32)            0
#  g1D)
#
#  flatten_16 (Flatten)        (None, 736)               0
#
#  dense_26 (Dense)            (None, 64)                47168
#
#  dense_27 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 1063590 (4.06 MB)
# Trainable params: 1063590 (4.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/5
# 55/55 [==============================] - 4s 58ms/step - loss: 1.2079 - accuracy: 0.5650
# Epoch 2/5
# 55/55 [==============================] - 2s 43ms/step - loss: 0.1849 - accuracy: 0.9636
# Epoch 3/5
# 55/55 [==============================] - 2s 37ms/step - loss: 0.0212 - accuracy: 0.9965
# Epoch 4/5
# 55/55 [==============================] - 2s 39ms/step - loss: 0.0066 - accuracy: 0.9987
# Epoch 5/5
# 55/55 [==============================] - 2s 29ms/step - loss: 0.0037 - accuracy: 0.9993
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0074 - accuracy: 0.9976
# test_acc: 0.9975833296775818 	 test_loss: 0.007354338187724352
# 375/375 [==============================] - 1s 3ms/step
# Confusion Matrix:
# [[2392    0    1    0    4    1]
#  [   0 2653    0    0    0    1]
#  [   2    0 2148    0    6    3]
#  [   0    0    0 2368    0    0]
#  [   1    0    2    0 1249    1]
#  [   0    0    0    0    7 1161]]
# Category: اقتصاد
# Precision: 0.99875
# Recall: 0.99750
# Accuracy: 0.99925
# F1 Score: 0.99812
# --------------------------------------
# Category: جامعه
# Precision: 1.00000
# Recall: 0.99962
# Accuracy: 0.99992
# F1 Score: 0.99981
# --------------------------------------
# Category: جهان
# Precision: 0.99861
# Recall: 0.99491
# Accuracy: 0.99883
# F1 Score: 0.99675
# --------------------------------------
# Category: سیاست
# Precision: 1.00000
# Recall: 1.00000
# Accuracy: 1.00000
# F1 Score: 1.00000
# --------------------------------------
# Category: فرهنگ
# Precision: 0.98657
# Recall: 0.99681
# Accuracy: 0.99825
# F1 Score: 0.99166
# --------------------------------------
# Category: ورزش
# Precision: 0.99486
# Recall: 0.99401
# Accuracy: 0.99892
# F1 Score: 0.99443
# --------------------------------------
# Training model with Embedding Dimension: 100, filters=32, kernel_size=7, maxpool=False
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_14 (Embedding)    (None, 50, 100)           1000000
#
#  conv1d_14 (Conv1D)          (None, 44, 32)            22432
#
#  flatten_17 (Flatten)        (None, 1408)              0
#
#  flatten_18 (Flatten)        (None, 1408)              0
#
#  dense_28 (Dense)            (None, 64)                90176
#
#  dense_29 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 1112998 (4.25 MB)
# Trainable params: 1112998 (4.25 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/5
# 55/55 [==============================] - 5s 64ms/step - loss: 1.2574 - accuracy: 0.5330
# Epoch 2/5
# 55/55 [==============================] - 2s 44ms/step - loss: 0.1852 - accuracy: 0.9634
# Epoch 3/5
# 55/55 [==============================] - 2s 28ms/step - loss: 0.0199 - accuracy: 0.9967
# Epoch 4/5
# 55/55 [==============================] - 1s 27ms/step - loss: 0.0066 - accuracy: 0.9988
# Epoch 5/5
# 55/55 [==============================] - 2s 31ms/step - loss: 0.0037 - accuracy: 0.9993
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0074 - accuracy: 0.9980
# test_acc: 0.9980000257492065 	 test_loss: 0.00744580989703536
# 375/375 [==============================] - 1s 2ms/step
# Confusion Matrix:
# [[2390    0    4    0    3    1]
#  [   0 2654    0    0    0    0]
#  [   1    0 2153    0    0    5]
#  [   0    0    0 2367    0    1]
#  [   0    0    4    0 1248    1]
#  [   1    0    1    0    2 1164]]
# Category: اقتصاد
# Precision: 0.99916
# Recall: 0.99666
# Accuracy: 0.99917
# F1 Score: 0.99791
# --------------------------------------
# Category: جامعه
# Precision: 1.00000
# Recall: 1.00000
# Accuracy: 1.00000
# F1 Score: 1.00000
# --------------------------------------
# Category: جهان
# Precision: 0.99584
# Recall: 0.99722
# Accuracy: 0.99875
# F1 Score: 0.99653
# --------------------------------------
# Category: سیاست
# Precision: 1.00000
# Recall: 0.99958
# Accuracy: 0.99992
# F1 Score: 0.99979
# --------------------------------------
# Category: فرهنگ
# Precision: 0.99601
# Recall: 0.99601
# Accuracy: 0.99917
# F1 Score: 0.99601
# --------------------------------------
# Category: ورزش
# Precision: 0.99317
# Recall: 0.99658
# Accuracy: 0.99900
# F1 Score: 0.99487
# --------------------------------------
# Training model with Embedding Dimension: 100, filters=32, kernel_size=7, maxpool=True
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_15 (Embedding)    (None, 50, 100)           1000000
#
#  conv1d_15 (Conv1D)          (None, 44, 32)            22432
#
#  max_pooling1d_7 (MaxPoolin  (None, 22, 32)            0
#  g1D)
#
#  flatten_19 (Flatten)        (None, 704)               0
#
#  dense_30 (Dense)            (None, 64)                45120
#
#  dense_31 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 1067942 (4.07 MB)
# Trainable params: 1067942 (4.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/5
# 55/55 [==============================] - 4s 53ms/step - loss: 1.2969 - accuracy: 0.5111
# Epoch 2/5
# 55/55 [==============================] - 3s 49ms/step - loss: 0.3027 - accuracy: 0.9352
# Epoch 3/5
# 55/55 [==============================] - 2s 28ms/step - loss: 0.0329 - accuracy: 0.9957
# Epoch 4/5
# 55/55 [==============================] - 2s 33ms/step - loss: 0.0093 - accuracy: 0.9982
# Epoch 5/5
# 55/55 [==============================] - 2s 40ms/step - loss: 0.0045 - accuracy: 0.9993
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0089 - accuracy: 0.9969
# test_acc: 0.996916651725769 	 test_loss: 0.00889451801776886
# 375/375 [==============================] - 1s 3ms/step
# Confusion Matrix:
# [[2386    0    6    0    2    4]
#  [   0 2653    0    0    0    1]
#  [   1    0 2152    0    0    6]
#  [   0    0    0 2368    0    0]
#  [   0    0    5    0 1246    2]
#  [   1    0    8    0    1 1158]]
# Category: اقتصاد
# Precision: 0.99916
# Recall: 0.99500
# Accuracy: 0.99883
# F1 Score: 0.99707
# --------------------------------------
# Category: جامعه
# Precision: 1.00000
# Recall: 0.99962
# Accuracy: 0.99992
# F1 Score: 0.99981
# --------------------------------------
# Category: جهان
# Precision: 0.99125
# Recall: 0.99676
# Accuracy: 0.99783
# F1 Score: 0.99400
# --------------------------------------
# Category: سیاست
# Precision: 1.00000
# Recall: 1.00000
# Accuracy: 1.00000
# F1 Score: 1.00000
# --------------------------------------
# Category: فرهنگ
# Precision: 0.99760
# Recall: 0.99441
# Accuracy: 0.99917
# F1 Score: 0.99600
# --------------------------------------
# Category: ورزش
# Precision: 0.98890
# Recall: 0.99144
# Accuracy: 0.99808
# F1 Score: 0.99017
# --------------------------------------

# %% [markdown]
# # part 2

# %% [markdown]
# **imdb**

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, LSTM, Dense, Flatten
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import numpy as np
import gensim.downloader as api

# Load and preprocess data
max_words = 10000
maxlen = 50
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=max_words)
word_index = imdb.get_word_index()
X_train = pad_sequences(X_train, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)

# Create embedding matrix
def create_embedding_matrix(word_index, max_words, embedding_dim):
    word_vectors = api.load("glove-wiki-gigaword-100")
    embedding_matrix = np.zeros((max_words, embedding_dim))
    for word, i in word_index.items():
        if i < max_words:
            try:
                embedding_vector = word_vectors[word]
                embedding_matrix[i] = embedding_vector
            except KeyError:
                embedding_matrix[i] = np.random.normal(size=(embedding_dim,))
    return embedding_matrix

embedding_dim = 100
embedding_matrix = create_embedding_matrix(word_index, max_words, embedding_dim)

# Define and compile the model
model = Sequential([
    Embedding(input_dim=max_words, output_dim=embedding_dim, input_length=maxlen, weights=[embedding_matrix], trainable=False),
    Conv1D(filters=32, kernel_size=5, activation='relu'),
    MaxPooling1D(pool_size=2),
    LSTM(32, return_sequences=True),
    LSTM(64),
    Flatten(),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=5, batch_size=64, validation_split=0.2)

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"test_acc: {test_acc:.5f} \t test_loss: {test_loss:.5f}")

# Predict and calculate metrics
y_pred = (model.predict(X_test) > 0.5).astype("int32")

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='binary')
recall = recall_score(y_test, y_pred, average='binary')
f1 = f1_score(y_test, y_pred, average='binary')
cm = confusion_matrix(y_test, y_pred)

print("Evaluation Metrics:")
print(f"Accuracy: {accuracy:.5f}")
print(f"Precision: {precision:.5f}")
print(f"Recall: {recall:.5f}")
print(f"F1 Score: {f1:.5f}")
print("Confusion Matrix:")
print(cm)
# Out:
# Epoch 1/5
# 313/313 [==============================] - 7s 10ms/step - loss: 0.6862 - accuracy: 0.5392 - val_loss: 0.6616 - val_accuracy: 0.6010
# Epoch 2/5
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6271 - accuracy: 0.6348 - val_loss: 0.6424 - val_accuracy: 0.6206
# Epoch 3/5
# 313/313 [==============================] - 3s 10ms/step - loss: 0.5681 - accuracy: 0.6939 - val_loss: 0.5865 - val_accuracy: 0.6710
# Epoch 4/5
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5231 - accuracy: 0.7272 - val_loss: 0.5923 - val_accuracy: 0.6782
# Epoch 5/5
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4830 - accuracy: 0.7587 - val_loss: 0.5895 - val_accuracy: 0.6762
# 782/782 [==============================] - 4s 4ms/step - loss: 0.5795 - accuracy: 0.6850
# test_acc: 0.68504 	 test_loss: 0.57953
# 782/782 [==============================] - 3s 3ms/step
# Evaluation Metrics:
# Accuracy: 0.68504
# Precision: 0.70913
# Recall: 0.62744
# F1 Score: 0.66579
# Confusion Matrix:
# [[9283 3217]
#  [4657 7843]]

# %% [markdown]
# **Persian Text Sentiment Dataset**

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.19.2-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests>=2.32.1 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.8 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, requests, dill, multiprocess, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# Successfully installed datasets-2.19.2 dill-0.3.8 multiprocess-0.70.16 requests-2.32.3 xxhash-3.4.1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, LSTM, Dense, Flatten
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from datasets import load_dataset
import numpy as np
import gensim.downloader as api

# Load and preprocess data
def load_persian_text_sentiment_dataset():
    dataset = load_dataset("SeyedAli/Persian-Text-Sentiment")
    return dataset

def preprocess_persian_text_sentiment_dataset(dataset):
    texts = [item['text'] for item in dataset['train']]
    labels = [item['label'] for item in dataset['train']]
    return texts, labels

def create_embedding_matrix(word_index, max_words, embedding_dim):
    word_vectors = api.load("glove-wiki-gigaword-100")
    embedding_matrix = np.zeros((max_words, embedding_dim))
    for word, i in word_index.items():
        if i < max_words:
            try:
                embedding_vector = word_vectors[word]
                embedding_matrix[i] = embedding_vector
            except KeyError:
                embedding_matrix[i] = np.random.normal(size=(embedding_dim,))
    return embedding_matrix

def train_model_with_lstm(embedding_dim, X_train, y_train, X_test, y_test, max_words, embedding_matrix, maxlen=50):
    model = Sequential()
    model.add(Embedding(max_words, embedding_dim, input_length=maxlen, weights=[embedding_matrix], trainable=False))
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(LSTM(32, return_sequences=True))
    model.add(LSTM(64))
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.fit(np.array(X_train), np.array(y_train), epochs=5, batch_size=64, validation_split=0.2)
    y_pred = (model.predict(np.array(X_test)) > 0.5).astype("int32")

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='binary')
    recall = recall_score(y_test, y_pred, average='binary')
    f1 = f1_score(y_test, y_pred, average='binary')
    cm = confusion_matrix(y_test, y_pred)

    print("Evaluation Metrics:")
    print(f"Accuracy: {accuracy:.5f}")
    print(f"Precision: {precision:.5f}")
    print(f"Recall: {recall:.5f}")
    print(f"F1 Score: {f1:.5f}")
    print("Confusion Matrix:")
    print(cm)

dataset = load_persian_text_sentiment_dataset()
X, y = preprocess_persian_text_sentiment_dataset(dataset)

max_words = 10000
maxlen = 50
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(X)
sequences = tokenizer.texts_to_sequences(X)
X = pad_sequences(sequences, maxlen=maxlen)

embedding_dim = 100
embedding_matrix = create_embedding_matrix(tokenizer.word_index, max_words, embedding_dim)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

train_model_with_lstm(embedding_dim, X_train, y_train, X_test, y_test, max_words, embedding_matrix)
# Out:
# Epoch 1/5
# 489/489 [==============================] - 10s 10ms/step - loss: 0.4709 - accuracy: 0.7700 - val_loss: 0.4130 - val_accuracy: 0.8116
# Epoch 2/5
# 489/489 [==============================] - 4s 9ms/step - loss: 0.3779 - accuracy: 0.8327 - val_loss: 0.3979 - val_accuracy: 0.8220
# Epoch 3/5
# 489/489 [==============================] - 5s 11ms/step - loss: 0.3344 - accuracy: 0.8582 - val_loss: 0.3986 - val_accuracy: 0.8210
# Epoch 4/5
# 489/489 [==============================] - 4s 9ms/step - loss: 0.2995 - accuracy: 0.8760 - val_loss: 0.4155 - val_accuracy: 0.8214
# Epoch 5/5
# 489/489 [==============================] - 4s 9ms/step - loss: 0.2669 - accuracy: 0.8941 - val_loss: 0.4852 - val_accuracy: 0.8022
# 524/524 [==============================] - 4s 4ms/step
# Evaluation Metrics:
# Accuracy: 0.80646
# Precision: 0.78931
# Recall: 0.83036
# F1 Score: 0.80931
# Confusion Matrix:
# [[6631 1837]
#  [1406 6882]]

# %% [markdown]
# **Persian News Dataset**

# %%
import numpy as np
from datasets import load_dataset
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, LSTM, Dense, Flatten
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import gensim.downloader as api

# Load and preprocess data
dataset = load_dataset("saied/persian_news_dataset", split="train", streaming=True)
docs = []
document_count = 40000
counter = 0
skip_counter = 0

for doc in dataset:
    if len(doc['title']) == 0 or len(doc['category']) == 0:
        skip_counter += 1
        if skip_counter % 10000 == 0:
            print(f'{skip_counter} skipped')
        continue
    docs.append(doc)
    counter += 1
    if counter == document_count:
        break

print(f"Number of documents processed: {len(docs)}")

texts = [doc['text'] for doc in docs]
labels = [doc['category'] for doc in docs]

max_words = 10000
max_length = 50

# Tokenize the text data
tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
x = pad_sequences(sequences, maxlen=max_length)

label_encoder = LabelEncoder()
y = label_encoder.fit_transform(labels)

# Split the data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Create embedding matrix
def create_embedding_matrix(word_index, max_words, embedding_dim):
    word_vectors = api.load("glove-wiki-gigaword-100")
    embedding_matrix = np.zeros((max_words, embedding_dim))
    for word, i in word_index.items():
        if i < max_words:
            try:
                embedding_vector = word_vectors[word]
                embedding_matrix[i] = embedding_vector
            except KeyError:
                embedding_matrix[i] = np.random.normal(size=(embedding_dim,))
    return embedding_matrix

embedding_dim = 100
embedding_matrix = create_embedding_matrix(tokenizer.word_index, max_words, embedding_dim)

# Define and compile the model
model = Sequential([
    Embedding(input_dim=max_words, output_dim=embedding_dim, input_length=max_length, weights=[embedding_matrix], trainable=False),
    Conv1D(filters=32, kernel_size=7, activation='relu'),
    MaxPooling1D(pool_size=2),
    LSTM(32, return_sequences=True),
    LSTM(64),
    Flatten(),
    Dense(10, activation="relu"),
    Dense(5, activation="relu"),
    Dense(len(set(y)), activation="softmax"),
])

model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# Train the model
model.summary()
model.fit(x_train, y_train, epochs=4, batch_size=512)

# Evaluate the model
print("-------------------------------------")
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"test_acc: {test_acc:.5f} \t test_loss: {test_loss:.5f}")

# Make predictions on the test set
y_pred_probs = model.predict(x_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(cm)

# Calculate precision, recall, and other metrics for each class
unique_categories = label_encoder.classes_

for i, category in enumerate(unique_categories):
    tp = cm[i, i]
    fp = cm[:, i].sum() - tp
    fn = cm[i, :].sum() - tp
    tn = cm.sum() - (tp + fp + fn)

    precision = tp / (tp + fp) if tp + fp > 0 else 0
    recall = tp / (tp + fn) if tp + fn > 0 else 0
    accuracy = (tp + tn) / cm.sum() if cm.sum() > 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    print(f"Category: {category}")
    print(f"Precision: {precision:.5f}")
    print(f"Recall: {recall:.5f}")
    print(f"Accuracy: {accuracy:.5f}")
    print(f"F1 Score: {f1_score:.5f}")
    print("----------------------------------------")
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1491: FutureWarning: The repository for saied/persian_news_dataset contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/saied/persian_news_dataset
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/1.25k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/5.35k [00:00<?, ?B/s]
# 10000 skipped
# 20000 skipped
# 30000 skipped
# 40000 skipped
# 50000 skipped
# 60000 skipped
# 70000 skipped
# 80000 skipped
# 90000 skipped
# 100000 skipped
# 110000 skipped
# 120000 skipped
# 130000 skipped
# 140000 skipped
# 150000 skipped
# 160000 skipped
# 170000 skipped
# 180000 skipped
# 190000 skipped
# 200000 skipped
# 210000 skipped
# 220000 skipped
# 230000 skipped
# 240000 skipped
# Number of documents processed: 40000
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 50, 100)           1000000
#
#  conv1d_5 (Conv1D)           (None, 44, 32)            22432
#
#  max_pooling1d_5 (MaxPoolin  (None, 22, 32)            0
#  g1D)
#
#  lstm_10 (LSTM)              (None, 22, 32)            8320
#
#  lstm_11 (LSTM)              (None, 64)                24832
#
#  flatten_5 (Flatten)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 10)                650
#
#  dense_9 (Dense)             (None, 5)                 55
#
#  dense_10 (Dense)            (None, 6)                 36
#
# =================================================================
# Total params: 1056325 (4.03 MB)
# Trainable params: 56325 (220.02 KB)
# Non-trainable params: 1000000 (3.81 MB)
# _________________________________________________________________
# Epoch 1/4
# 55/55 [==============================] - 5s 10ms/step - loss: 1.6892 - accuracy: 0.2067
# Epoch 2/4
# 55/55 [==============================] - 0s 8ms/step - loss: 1.5019 - accuracy: 0.3722
# Epoch 3/4
# 55/55 [==============================] - 0s 8ms/step - loss: 1.3919 - accuracy: 0.4449
# Epoch 4/4
# 55/55 [==============================] - 0s 8ms/step - loss: 1.2355 - accuracy: 0.5337
# -------------------------------------
# 375/375 [==============================] - 3s 4ms/step - loss: 1.1117 - accuracy: 0.6122
# test_acc: 0.61217 	 test_loss: 1.11169
# 375/375 [==============================] - 2s 4ms/step
# Confusion Matrix:
# [[1575  579    0  244    0    0]
#  [   9 2257    0  383    0    5]
#  [ 304   36  444 1372    0    3]
#  [   1  299    2 2064    0    2]
#  [   0 1039    0  214    0    0]
#  [  29   20    1  112    0 1006]]
# Category: اقتصاد
# Precision: 0.82117
# Recall: 0.65680
# Accuracy: 0.90283
# F1 Score: 0.72984
# ----------------------------------------
# Category: جامعه
# Precision: 0.53357
# Recall: 0.85041
# Accuracy: 0.80250
# F1 Score: 0.65572
# ----------------------------------------
# Category: جهان
# Precision: 0.99329
# Recall: 0.20565
# Accuracy: 0.85683
# F1 Score: 0.34075
# ----------------------------------------
# Category: سیاست
# Precision: 0.47027
# Recall: 0.87162
# Accuracy: 0.78092
# F1 Score: 0.61092
# ----------------------------------------
# Category: فرهنگ
# Precision: 0.00000
# Recall: 0.00000
# Accuracy: 0.89558
# F1 Score: 0.00000
# ----------------------------------------
# Category: ورزش
# Precision: 0.99016
# Recall: 0.86130
# Accuracy: 0.98567
# F1 Score: 0.92125
# ----------------------------------------
